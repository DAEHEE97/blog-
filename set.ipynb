# %%
s = set()
type(s)
# Out:
# set

# %%
s2 = {}
type(s2)
# Out:
# dict

# %% [markdown]
# ---

# %%
s.add(1)

# %%
s.add(5)

# %%
s.add(3)

# %%
s
# Out:
# {1, 3, 5}

# %% [markdown]
# ---

# %%
lst = list(s)

# %%
lst
# Out:
# [1, 3, 5]
