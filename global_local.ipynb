# %% [markdown]
# # 전역변수(Global Variable)와 지역변수(Local Variable)

# %% [markdown]
# ---

# %% [markdown]
# - 전역변수는 함수 밖에서 선언되는 변수로서, 모든 함수에서 접근이 가능합니다.
# - 전역변수는 프로그램이 시작될 때 메모리에 할당되며, 프로그램이 종료될 때까지 유지됩니다.
#
#
# - 지역변수는 함수 내에서 선언되는 변수로서, 해당 함수 내에서만 접근이 가능합니다.
# - 지역변수는 함수가 호출될 때마다 새로운 메모리 공간이 할당되며, 함수가 반환될 때 메모리에서 제거됩니다.

# %% [markdown]
# ---

# %%
a = 10  # 전역변수

def my_func():
    
    b = 20  # 지역변수
    
    print(a)
    print(b)

my_func()  # 출력 결과: 10 20

print(b)   # NameError: name 'b' is not defined
# Out:
# 10
# 20
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 12
#       8     print(b)
#      10 my_func()  # 출력 결과: 10 20
# ---> 12 print(b)   # NameError: name 'b' is not defined
#
# NameError: name 'b' is not defined

# %% [markdown]
# ---

# %% [markdown]
# ## global
#
# - 전역 변수를 함수 내에서 수정하고자 할 때 global 키워드를 사용
#
# - 전역 변수를 남발하면 코드의 복잡도가 증가하고, 예상치 못한 결과가 발생할 수 있기 때문에 가능한 지역 변수를 사용하는 것이 좋습니다.
#
# - 따라서 global 키워드를 사용하는 경우를 제한하고, 전역 변수의 사용을 최소화

# %%
cnt = 0

def increment_count():
    
    print("hello")
    cnt += 1

increment_count()
print(cnt)
# Out:
# hello
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[2], line 8
#       5     print("hello")
#       6     cnt += 1
# ----> 8 increment_count()
#       9 print(cnt)
#
# Cell In[2], line 6, in increment_count()
#       3 def increment_count():
#       5     print("hello")
# ----> 6     cnt += 1
#
# UnboundLocalError: cannot access local variable 'cnt' where it is not associated with a value

# %% [markdown]
# ---

# %%
cnt = 0

def increment_count():
    
    print("hello")
    global cnt
    cnt += 1

increment_count()
print(cnt)
# Out:
# hello
# 1
