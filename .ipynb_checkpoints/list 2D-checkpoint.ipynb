# %% [markdown]
# # 2D List
#
# - 2차원 리스트는 가로×세로 형태로 이루어져 있으며 행(row)과 열(column) 모두 0부터 시작합니다.

# %%
a = [[10, 20], [30, 40], [50, 60]]
a
# Out:
# [[10, 20], [30, 40], [50, 60]]

# %%
a = [[10, 20],
     [30, 40],
     [50, 60] ]
a
# Out:
# [[10, 20], [30, 40], [50, 60]]

# %%
a[0][0]
# Out:
# 10

# %%
a[1][1]
# Out:
# 40

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 톱니형 리스트 (jagged list)
#
# - 2차원 리스트 [[10, 20], [30, 40], [50, 60]]은 가로 크기가 일정한 사각형 리스트입니다.
#
# - 특히 파이썬에서는 가로 크기가 불규칙한 톱니형 리스트(jagged list)도 만들 수 있습니다.

# %%
a = [[10, 20],
     [500, 600, 700],
     [9],
     [30, 40],
     [8],
     [800, 900, 1000]]
a
# Out:
# [[10, 20], [500, 600, 700], [9], [30, 40], [8], [800, 900, 1000]]

# %%
pprint(a, indent=4, width=40)
# Out:
# [   [10, 20],
#     [500, 600, 700],
#     [9],
#     [30, 40],
#     [8],
#     [800, 900, 1000]]

# %% [markdown]
# ## 2D Tuple

# %%
a = ((10, 20), (30, 40), (50, 60))    # 튜플 안에 튜플을 넣은 2차원 튜플
b = ([10, 20], [30, 40], [50, 60])    # 튜플 안에 리스트를 넣음
c = [(10, 20), (30, 40), (50, 60)]    # 리스트 안에 튜플을 넣음

# %% [markdown]
# ## 알아보기 쉽게 출력

# %%
from pprint import pprint

# indent는 들여쓰기 칸 수, width는 가로 폭입니다. 각자 상황에 맞게 들여쓰기 칸 수와 가로 폭을 조절해서 사용해보세요.
a = [[10, 20],
     [30, 40],
     [50, 60] ]

pprint(a, indent=4, width=20)
# Out:
# [   [10, 20],
#     [30, 40],
#     [50, 60]]

# %% [markdown]
# ---

# %% [markdown]
# # List 입력

# %%
lst = [[0 for j in range(2)] for i in range(3)]
lst
# Out:
# [[0, 0], [0, 0], [0, 0]]

# %%
lst = [[0] * 2 for i in range(3)]
lst
# Out:
# [[0, 0], [0, 0], [0, 0]]

# %%
lst = []    # 빈 리스트 생성
 
for i in range(3):
    lst_in = []              # 안쪽 리스트로 사용할 빈 리스트 생성
    
    for j in range(2):
        lst_in.append(0)     # 안쪽 리스트에 0 추가
    
    lst.append(lst_in)       # 전체 리스트에 안쪽 리스트를 추가
    
print(lst)
# Out:
# [[0, 0], [0, 0], [0, 0]]

# %%
pprint(lst, indent=4, width=20)
# Out:
# [   [0, 0],
#     [0, 0],
#     [0, 0]]

# %% [markdown]
# ## sorted로 2차원 리스트 정렬하기
#
# - sorted(반복가능한객체, key=정렬함수, reverse=True 또는 False)
#
# - 다음은 학생 정보가 저장된 2차원 리스트를 정렬합니다.

# %%
students = [
    ['john', 'C', 19],
    ['maria', 'A', 25],
    ['andrew', 'B', 7]
]
 
print(sorted(students, key=lambda student: student[1]))  # 안쪽 리스트의 인덱스 1을 기준으로 정렬
print(sorted(students, key=lambda student: student[2]))  # 안쪽 리스트의 인덱스 2를 기준으로 정렬
# Out:
# [['maria', 'A', 25], ['andrew', 'B', 7], ['john', 'C', 19]]
# [['andrew', 'B', 7], ['john', 'C', 19], ['maria', 'A', 25]]

# %% [markdown]
# ---

# %% [markdown]
# # 2D List 출력

# %% [markdown]
# ## `for x,y in lst`

# %%
lst = [[10, 20], [30, 40], [50, 60]]

# %%
for x, y in lst:    # 리스트의 가로 한 줄(안쪽 리스트)에서 요소 두 개를 꺼냄
    print(x,y)
# Out:
# 10 20
# 30 40
# 50 60

# %%
for i in lst:
    print(i[0],i[1])
# Out:
# 10 20
# 30 40
# 50 60

# %% [markdown]
# ## Nested for loop

# %%
lst = [[10, 20], [30, 40], [50, 60]]
 
for i in lst:        # 전체 리스트에서 가로 한 줄씩 꺼내 옵니다(안쪽 리스트를 통째로 꺼내 옴). 
    for j in i:      # 다시 한 줄(안쪽 리스트) i에서 요소 j를 하나씩 꺼내면 됩니다.
        print(j, end=' ')
    print()
# Out:
# 10 20
# 30 40
# 50 60

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## for range len

# %%
lst = [[10, 20], [30, 40], [50, 60]]
lst
# Out:
# [[10, 20], [30, 40], [50, 60]]

# %%
from pprint import pprint

# indent는 들여쓰기 칸 수, width는 가로 폭입니다. 

pprint(lst, indent=4, width=20)
# Out:
# [   [10, 20],
#     [30, 40],
#     [50, 60]]

# %%
for i in range(len(lst)):            # 전체 리스트 크기 : 세로 크기
    for j in range(len(lst[i])):     # 내부 리스트 : 가로 크기
        print(lst[i][j], end=' ')
    print()
# Out:
# 10 20
# 30 40
# 50 60

# %% [markdown]
# ## while

# %%
lst = [[10, 20], [30, 40], [50, 60]]

# %%
i = 0
while i < len(lst):    # 반복할 때 리스트의 크기 활용(세로 크기)
    x, y = lst[i]      # 요소 두 개를 한꺼번에 가져오기
    print(x, y)
    i += 1           # 인덱스를 1 증가시킴
# Out:
# 10 20
# 30 40
# 50 60

# %%
lst = [[10, 20], [30, 40], [50, 60]]
 
i = 0
while i < len(lst):           # 세로 크기
    
    j = 0
    
    while j < len(lst[i]):    # 가로 크기
        print(lst[i][j], end=' ')
        j += 1              # 가로 인덱스를 1 증가시킴
    
    print()
    i += 1                  # 세로 인덱스를 1 증가시킴
# Out:
# 10 20
# 30 40
# 50 60
